# %% [markdown]
# ## About Dataset
#
# This dataset contains information about used cars.
# This data can be used for a lot of purposes such as price prediction to exemplify the use of linear regression in Machine Learning.
# The columns in the given dataset are as follows:
#
# - name
# - year
# - selling_price
# - km_driven
# - fuel
# - seller_type
# - transmission
# - Owner
#
# prices are in lakhs

# %% [markdown]
# ## Importing required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import datetime
from sklearn.preprocessing import StandardScaler
import datetime
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error,r2_score
from tkinter import *
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('car data.csv')

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.shape
# Out:
# (301, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.isnull().sum() # there is no null values
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %% [raw]
# we can see that average selling price is 4.6 lakh and avg present price is 7.6 lakhs as well maximum prices are also given

# %% [markdown]
# # EDA

# %%
car_counts = df['Car_Name'].value_counts().head(10)
car_counts
# Out:
# city             26
# corolla altis    16
# verna            14
# fortuner         11
# brio             10
# i20               9
# ciaz              9
# innova            9
# grand i10         8
# jazz              7
# Name: Car_Name, dtype: int64

# %%
sns.set_style("whitegrid")
sns.set(rc={'figure.figsize':(12,8)})
sns.countplot(y='Car_Name', data=df, order=car_counts.index, palette='Set2')
plt.title('Top 10 Car Counts')
plt.xlabel('Count')
plt.ylabel('Car Name')
plt.show()

# %% [markdown]
# Most number of cars are honda city and corolla altis

# %%
sns.set(style='darkgrid')
fig, axs = plt.subplots(2, 2, figsize=(12, 8))
sns.countplot(x='Fuel_Type', data=df, ax=axs[0][0])
sns.countplot(x='Seller_Type', data=df, ax=axs[0][1])
sns.countplot(x='Transmission', data=df, ax=axs[1][0])
sns.countplot(x='Owner', data=df, ax=axs[1][1])
plt.show()

# %%
sns.countplot(x='Year',data=df)
plt.xticks(rotation=90);

# %% [markdown]
# - most number of cars are from year 2015 and 2016
# - least number of cars are from 2003,04, 05, 06, 07, 08, 09 and 2018

# %%
# feature transformation
# Calculate the age of each car
current_year = datetime.datetime.now().year
df['Age'] = current_year - df['Year']

# Drop the Year column
df.drop('Year', axis=1, inplace=True)

# %%
df.head()
# Out:
#   Car_Name  Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0     ritz           3.35           5.59       27000    Petrol      Dealer
# 1      sx4           4.75           9.54       43000    Diesel      Dealer
# 2     ciaz           7.25           9.85        6900    Petrol      Dealer
# 3  wagon r           2.85           4.15        5200    Petrol      Dealer
# 4    swift           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  Age
# 0       Manual      0    9
# 1       Manual      0   10
# 2       Manual      0    6
# 3       Manual      0   12
# 4       Manual      0    9

# %% [markdown]
# #### Distribution of numerical features

# %%
sns.set(style="darkgrid", font_scale=1.2)
fig, axs = plt.subplots(nrows=5, figsize=(10, 20))

# Plot the distribution of Selling_Price
sns.distplot(df['Selling_Price'], ax=axs[0], color='red')
axs[0].set(xlabel='Selling Price', ylabel='Density')

# Plot the distribution of Present_Price
sns.distplot(df['Present_Price'], ax=axs[1], color='green')
axs[1].set(xlabel='Present Price', ylabel='Density')

# Plot the distribution of Kms_Driven
sns.distplot(df['Kms_Driven'], ax=axs[2], color='blue')
axs[2].set(xlabel='Kilometers Driven', ylabel='Density')

# Plot the distribution of Owner
sns.distplot(df['Owner'], ax=axs[3], color='purple')
axs[3].set(xlabel='Owner', ylabel='Density')

# Plot the distribution of Age
sns.distplot(df['Age'], ax=axs[4], color='orange')
axs[4].set(xlabel='Age', ylabel='Density')

# Adjust the spacing between subplots
plt.subplots_adjust(hspace=0.4)

# Show the plots
plt.show()

# %% [markdown]
# - They all are right skewed

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(10, 10), dpi=90)
num_features = ['Present_Price', 'Kms_Driven', 'Age', 'Owner']
target = 'Selling_Price'
c = '#0055ff'

for i in range(len(num_features)):
    row = i // 2
    col = i % 2
    ax[row, col].scatter(df[num_features[i]], df[target], color=c, edgecolors='w', linewidths=0.25)
    ax[row, col].set_title('{} vs. {}'.format(target, num_features[i]), size=12)
    ax[row, col].set_xlabel(num_features[i], size=12)
    ax[row, col].set_ylabel(target, size=12)
    ax[row, col].grid()

plt.suptitle('Selling Price vs. Numerical Features', size=20)
plt.tight_layout()
plt.show()

# %%
sns.stripplot(x='Fuel_Type', y='Selling_Price', data=df)
plt.title('Selling Price by Fuel Type')
plt.show()

sns.stripplot(x='Seller_Type', y='Selling_Price', data=df)
plt.title('Selling Price by Seller Type')
plt.show()

sns.stripplot(x='Transmission', y='Selling_Price', data=df)
plt.title('Selling Price by Transmission')
plt.show()

# %% [markdown]
# - Diesel cars have a higher selling price compared to those that use petrol or CNG.
# - Dealership-sold cars have a higher selling price compared to individual-sold cars.
# - Automatic cars have a higher selling price compared to manual cars.

# %%
# Highest selling price car

highest_selling_price_car = df.sort_values('Selling_Price', ascending=False).iloc[0]
print("The car with the highest selling price is:")
print(highest_selling_price_car)
# Out:
# The car with the highest selling price is:
# Car_Name         land cruiser
# Selling_Price            35.0
# Present_Price            92.6
# Kms_Driven              78000
# Fuel_Type              Diesel
# Seller_Type            Dealer
# Transmission           Manual
# Owner                       0
# Age                        13
# Name: 86, dtype: object

# %%
# lowest selling price

lowest_selling_price_car = df.sort_values('Selling_Price', ascending=True).iloc[0]
print("The car with the lowest selling price is:")
print(lowest_selling_price_car)
# Out:
# The car with the lowest selling price is:
# Car_Name         Bajaj Pulsar 150
# Selling_Price                 0.1
# Present_Price                0.75
# Kms_Driven                  92233
# Fuel_Type                  Petrol
# Seller_Type            Individual
# Transmission               Manual
# Owner                           0
# Age                            17
# Name: 200, dtype: object

# %% [markdown]
# # Encoding

# %%
df['Fuel_Type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG'], dtype=object)

# %%
df['Fuel_Type'] = df['Fuel_Type'].map({'Petrol':0,'Diesel':1,'CNG':2})

# %%
df['Seller_Type'].unique()
# Out:
# array(['Dealer', 'Individual'], dtype=object)

# %%
df['Seller_Type'] = df['Seller_Type'].map({'Dealer':0,'Individual':1})

# %%
df['Transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
df['Transmission'] =df['Transmission'].map({'Manual':0,'Automatic':1})

# %%
df.head()
# Out:
#   Car_Name  Selling_Price  Present_Price  Kms_Driven  Fuel_Type  Seller_Type  \
# 0     ritz           3.35           5.59       27000          0            0
# 1      sx4           4.75           9.54       43000          1            0
# 2     ciaz           7.25           9.85        6900          0            0
# 3  wagon r           2.85           4.15        5200          0            0
# 4    swift           4.60           6.87       42450          1            0
#
#    Transmission  Owner  Age
# 0             0      0    9
# 1             0      0   10
# 2             0      0    6
# 3             0      0   12
# 4             0      0    9

# %% [markdown]
# # correlation analysis

# %%
correlation = df.corr()
correlation.style.background_gradient(cmap='summer')
# Out:
# <style  type="text/css" >
# #T_1fe56_row0_col0,#T_1fe56_row1_col1,#T_1fe56_row2_col2,#T_1fe56_row3_col3,#T_1fe56_row4_col4,#T_1fe56_row5_col5,#T_1fe56_row6_col6,#T_1fe56_row7_col7{
#             background-color:  #ffff66;
#             color:  #000000;
#         }#T_1fe56_row0_col1{
#             background-color:  #ebf566;
#             color:  #000000;
#         }#T_1fe56_row0_col2{
#             background-color:  #1e8e66;
#             color:  #000000;
#         }#T_1fe56_row0_col3{
#             background-color:  #a3d166;
#             color:  #000000;
#         }#T_1fe56_row0_col4,#T_1fe56_row0_col6,#T_1fe56_row0_col7,#T_1fe56_row4_col0,#T_1fe56_row4_col1,#T_1fe56_row4_col2,#T_1fe56_row4_col3,#T_1fe56_row4_col5{
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }#T_1fe56_row0_col5{
#             background-color:  #67b366;
#             color:  #000000;
#         }#T_1fe56_row1_col0{
#             background-color:  #ecf666;
#             color:  #000000;
#         }#T_1fe56_row1_col2{
#             background-color:  #46a266;
#             color:  #000000;
#         }#T_1fe56_row1_col3{
#             background-color:  #96cb66;
#             color:  #000000;
#         }#T_1fe56_row1_col4{
#             background-color:  #068266;
#             color:  #f1f1f1;
#         }#T_1fe56_row1_col5{
#             background-color:  #63b166;
#             color:  #000000;
#         }#T_1fe56_row1_col6{
#             background-color:  #168a66;
#             color:  #000000;
#         }#T_1fe56_row1_col7{
#             background-color:  #3a9c66;
#             color:  #000000;
#         }#T_1fe56_row2_col0{
#             background-color:  #5faf66;
#             color:  #000000;
#         }#T_1fe56_row2_col1{
#             background-color:  #79bc66;
#             color:  #000000;
#         }#T_1fe56_row2_col3{
#             background-color:  #62b066;
#             color:  #000000;
#         }#T_1fe56_row2_col4{
#             background-color:  #4aa466;
#             color:  #000000;
#         }#T_1fe56_row2_col5{
#             background-color:  #369a66;
#             color:  #000000;
#         }#T_1fe56_row2_col6{
#             background-color:  #299466;
#             color:  #000000;
#         }#T_1fe56_row2_col7{
#             background-color:  #9dce66;
#             color:  #000000;
#         }#T_1fe56_row3_col0{
#             background-color:  #afd766;
#             color:  #000000;
#         }#T_1fe56_row3_col1{
#             background-color:  #a1d066;
#             color:  #000000;
#         }#T_1fe56_row3_col2{
#             background-color:  #3e9e66;
#             color:  #000000;
#         }#T_1fe56_row3_col4,#T_1fe56_row5_col6{
#             background-color:  #209066;
#             color:  #000000;
#         }#T_1fe56_row3_col5{
#             background-color:  #229066;
#             color:  #000000;
#         }#T_1fe56_row3_col6{
#             background-color:  #078366;
#             color:  #f1f1f1;
#         }#T_1fe56_row3_col7{
#             background-color:  #259266;
#             color:  #000000;
#         }#T_1fe56_row4_col6{
#             background-color:  #329866;
#             color:  #000000;
#         }#T_1fe56_row4_col7{
#             background-color:  #399c66;
#             color:  #000000;
#         }#T_1fe56_row5_col0{
#             background-color:  #97cb66;
#             color:  #000000;
#         }#T_1fe56_row5_col1,#T_1fe56_row7_col2{
#             background-color:  #91c866;
#             color:  #000000;
#         }#T_1fe56_row5_col2{
#             background-color:  #3d9e66;
#             color:  #000000;
#         }#T_1fe56_row5_col3{
#             background-color:  #51a866;
#             color:  #000000;
#         }#T_1fe56_row5_col4{
#             background-color:  #50a866;
#             color:  #000000;
#         }#T_1fe56_row5_col7{
#             background-color:  #309866;
#             color:  #000000;
#         }#T_1fe56_row6_col0{
#             background-color:  #4ca666;
#             color:  #000000;
#         }#T_1fe56_row6_col1{
#             background-color:  #58ac66;
#             color:  #000000;
#         }#T_1fe56_row6_col2{
#             background-color:  #2c9666;
#             color:  #000000;
#         }#T_1fe56_row6_col3,#T_1fe56_row7_col3{
#             background-color:  #389c66;
#             color:  #000000;
#         }#T_1fe56_row6_col4{
#             background-color:  #6fb766;
#             color:  #000000;
#         }#T_1fe56_row6_col5{
#             background-color:  #1b8d66;
#             color:  #000000;
#         }#T_1fe56_row6_col7{
#             background-color:  #56ab66;
#             color:  #000000;
#         }#T_1fe56_row7_col0{
#             background-color:  #339966;
#             color:  #000000;
#         }#T_1fe56_row7_col1{
#             background-color:  #5eae66;
#             color:  #000000;
#         }#T_1fe56_row7_col4{
#             background-color:  #61b066;
#             color:  #000000;
#         }#T_1fe56_row7_col5{
#             background-color:  #0f8766;
#             color:  #000000;
#         }#T_1fe56_row7_col6{
#             background-color:  #3f9f66;
#             color:  #000000;
#         }</style><table id="T_1fe56_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Selling_Price</th>        <th class="col_heading level0 col1" >Present_Price</th>        <th class="col_heading level0 col2" >Kms_Driven</th>        <th class="col_heading level0 col3" >Fuel_Type</th>        <th class="col_heading level0 col4" >Seller_Type</th>        <th class="col_heading level0 col5" >Transmission</th>        <th class="col_heading level0 col6" >Owner</th>        <th class="col_heading level0 col7" >Age</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1fe56_level0_row0" class="row_heading level0 row0" >Selling_Price</th>
#                         <td id="T_1fe56_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_1fe56_row0_col1" class="data row0 col1" >0.878983</td>
#                         <td id="T_1fe56_row0_col2" class="data row0 col2" >0.029187</td>
#                         <td id="T_1fe56_row0_col3" class="data row0 col3" >0.509467</td>
#                         <td id="T_1fe56_row0_col4" class="data row0 col4" >-0.550724</td>
#                         <td id="T_1fe56_row0_col5" class="data row0 col5" >0.367128</td>
#                         <td id="T_1fe56_row0_col6" class="data row0 col6" >-0.088344</td>
#                         <td id="T_1fe56_row0_col7" class="data row0 col7" >-0.236141</td>
#             </tr>
#             <tr>
#                         <th id="T_1fe56_level0_row1" class="row_heading level0 row1" >Present_Price</th>
#                         <td id="T_1fe56_row1_col0" class="data row1 col0" >0.878983</td>
#                         <td id="T_1fe56_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_1fe56_row1_col2" class="data row1 col2" >0.203647</td>
#                         <td id="T_1fe56_row1_col3" class="data row1 col3" >0.440415</td>
#                         <td id="T_1fe56_row1_col4" class="data row1 col4" >-0.512030</td>
#                         <td id="T_1fe56_row1_col5" class="data row1 col5" >0.348715</td>
#                         <td id="T_1fe56_row1_col6" class="data row1 col6" >0.008057</td>
#                         <td id="T_1fe56_row1_col7" class="data row1 col7" >0.047584</td>
#             </tr>
#             <tr>
#                         <th id="T_1fe56_level0_row2" class="row_heading level0 row2" >Kms_Driven</th>
#                         <td id="T_1fe56_row2_col0" class="data row2 col0" >0.029187</td>
#                         <td id="T_1fe56_row2_col1" class="data row2 col1" >0.203647</td>
#                         <td id="T_1fe56_row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_1fe56_row2_col3" class="data row2 col3" >0.166801</td>
#                         <td id="T_1fe56_row2_col4" class="data row2 col4" >-0.101419</td>
#                         <td id="T_1fe56_row2_col5" class="data row2 col5" >0.162510</td>
#                         <td id="T_1fe56_row2_col6" class="data row2 col6" >0.089216</td>

# %% [markdown]
# # Train-test split

# %%
X = df.drop(['Car_Name','Selling_Price'],axis=1)
y = df['Selling_Price']

# %%
X.head()

# %%
y.head()

# %% [markdown]
# ### Feature importance

# %%
fea = ExtraTreesRegressor()
fea.fit(X,y)

# %%
feat_importances = pd.Series(fea.feature_importances_, index=X.columns)
feat_importances.nlargest(5).plot(kind='barh')
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.20, random_state = 42)

# %%
print('X_train shape: ', X_train.shape)
print('X_test shape: ', X_test.shape)
print('y_train shape: ', y_train.shape)
print('y_test shape: ',y_test.shape)

# %% [markdown]
# # Standard Scaler

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # Model Building

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)

rf = RandomForestRegressor()
rf.fit(X_train,y_train)

xgb = GradientBoostingRegressor()
xgb.fit(X_train,y_train)

xg = XGBRegressor()
xg.fit(X_train,y_train)

# %%
# make predictions on the test data
y_pred1 = lr.predict(X_test)
y_pred2 = rf.predict(X_test)
y_pred3 = xgb.predict(X_test)
y_pred4 = xg.predict(X_test)

# %% [markdown]
# ### Linear Regression

# %%
print("R_squared:", r2_score(y_test,y_pred1))
print("MAE:", mean_absolute_error(y_test,y_pred1))
print("MSE:", mean_squared_error(y_test,y_pred1))
print("RMSE:",np.sqrt(mean_squared_error(y_test,y_pred1)))

# %% [markdown]
# ### Random Forest

# %%
print("R_squared:", r2_score(y_test,y_pred2))
print("MAE:", mean_absolute_error(y_test,y_pred2))
print("MSE:", mean_squared_error(y_test,y_pred2))
print("RMSE :",np.sqrt(mean_squared_error(y_test,y_pred2)))

# %% [markdown]
# ### GradientBoostingRegressor

# %%
print("R_squared:", r2_score(y_test,y_pred3))
print("MAE:", mean_absolute_error(y_test,y_pred3))
print("MSE:", mean_squared_error(y_test,y_pred3))
print("RMSE :",np.sqrt(mean_squared_error(y_test,y_pred3)))

# %% [markdown]
# ### XGBRegressor

# %%
print("R_squared:", r2_score(y_test,y_pred4))
print("MAE:", mean_absolute_error(y_test,y_pred4))
print("MSE:", mean_squared_error(y_test,y_pred4))
print("RMSE :",np.sqrt(mean_squared_error(y_test,y_pred4)))

# %% [markdown]
# ### GradientBoostingRegressor is our best model with 0.97 R_square

# %%
plt.scatter(y_test,y_pred4)

# %% [markdown]
# # Saving Model for deployment

# %%
xg = XGBRegressor()
xg_final = xg.fit(X,y)

# %%
xg_final.save_model('car prediction model.json')

# %% [markdown]
# # Prediction on new data

# %%
data_new = pd.DataFrame({
    'Present_Price':7,
    'Kms_Driven':300000,
    'Fuel_Type':2,
    'Seller_Type':1,
    'Transmission':1,
    'Owner':3,
    'Age':10
},index=[0])

# %%
import xgboost as xgb
model = xgb.XGBRegressor()
model.load_model('car prediction model.json')

# %%
model.predict(data_new)

# %% [markdown]
# # GUI

# %%
def show_entry_fields():
    p1=float(e1.get())
    p2=float(e2.get())
    p3=float(e3.get())
    p4=float(e4.get())
    p5=float(e5.get())
    p6=float(e6.get())
    p7=float(e7.get())
    
    model = joblib.load('car_price_predictor')
    data_new = pd.DataFrame({
    'Present_Price':p1,
    'Kms_Driven':p2,
    'Fuel_Type':p3,
    'Seller_Type':p4,
    'Transmission':p5,
    'Owner':p6,
    'Age':p7
},index=[0])
    result=model.predict(data_new)
    Label(master, text="Car Purchase amount").grid(row=8)
    Label(master, text=result).grid(row=10)
    print("Car Purchase amount", result[0])
    
master = Tk()
master.title("Car Price Prediction Using Machine Learning")
label = Label(master, text = "Car Price Prediction Using Machine Learning"
                          , bg = "black", fg = "white"). \
                               grid(row=0,columnspan=2)


Label(master, text="Present_Price").grid(row=1)
Label(master, text="Kms_Driven").grid(row=2)
Label(master, text="Fuel_Type").grid(row=3)
Label(master, text="Seller_Type").grid(row=4)
Label(master, text="Transmission").grid(row=5)
Label(master, text="Owner").grid(row=6)
Label(master, text="Age").grid(row=7)


e1 = Entry(master)
e2 = Entry(master)
e3 = Entry(master)
e4 = Entry(master)
e5 = Entry(master)
e6 = Entry(master)
e7 = Entry(master)


e1.grid(row=1, column=1)
e2.grid(row=2, column=1)
e3.grid(row=3, column=1)
e4.grid(row=4, column=1)
e5.grid(row=5, column=1)
e6.grid(row=6, column=1)
e7.grid(row=7, column=1)


Button(master, text='Predict', command=show_entry_fields).grid()

mainloop()
